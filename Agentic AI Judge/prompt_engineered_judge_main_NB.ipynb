# %% [markdown]
# ## Initialization

# %%
# !pip install transformers accelerate huggingface_hub pyyaml tqdm scipy
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.55.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.34.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (1.1.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 30.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 38.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import yaml
import json

# %%
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    total_vram = torch.cuda.get_device_properties(0).total_memory / (1024**3)
    print(f"✅ Using GPU: {gpu_name} ({total_vram:.1f} GB VRAM)")
else:
    raise RuntimeError("❌ No GPU detected in Colab runtime!")
# Out:
# ✅ Using GPU: Tesla T4 (14.7 GB VRAM)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# EDIT this path to your project (quote path if it has spaces)
PROJECT_DIR = "/content/drive/MyDrive/LLM_Project"

# Change to project dir
# %cd "{PROJECT_DIR}"

# Confirm files
# !ls -la
# !ls -la LLM || true
# Out:
# /content/drive/MyDrive/LLM_Project
# total 274
# -rw------- 1 root root 235640 Aug 11 12:27 agentic_judge
# -rw------- 1 root root   2220 Aug 10 21:05 criteria.yml
# -rw------- 1 root root    892 Aug 10 17:11 domain_glossary.csv
# drwx------ 2 root root   4096 Aug 11 11:42 LLM
# -rw------- 1 root root  22788 Aug 10 20:07 LLM_dataset.csv
# -rw------- 1 root root   9634 Aug 11 12:23 main.py
# drwx------ 2 root root   4096 Aug 11 11:42 results
# total 47
# -rw------- 1 root root  5595 Aug 10 19:41 1.py
# -rw------- 1 root root 15818 Aug 10 19:32 2.py
# -rw------- 1 root root  5445 Aug 10 23:21 agent_tools.py
# -rw------- 1 root root     0 Aug 10 14:26 __init__.py
# drwx------ 2 root root  4096 Aug 11 11:42 .ipynb_checkpoints
# -rw------- 1 root root  1728 Aug 10 20:35 llm_api.py
# -rw------- 1 root root   599 Aug 10 12:50 logger.py
# -rw------- 1 root root   869 Aug 10 20:40 memory.py
# -rw------- 1 root root  7981 Aug 10 22:06 planner.py
# drwx------ 2 root root  4096 Aug 10 20:11 __pycache__

# %%
import sys, os
import importlib # Import importlib to reload modules

LLM_DIR = os.path.join(PROJECT_DIR, 'LLM')
if LLM_DIR not in sys.path:
    sys.path.insert(0, LLM_DIR)

# Import and reload package components
import logger
importlib.reload(logger)
from logger import AgentLogger

import llm_api
importlib.reload(llm_api)
from llm_api import LLM


# Import other components
import planner
from memory import Memory
from agent_tools import Toolset

importlib.reload(planner)


print("Imported LLM package components successfully.")
# Out:
# Imported LLM package components successfully.

# %%
# Initialize model wrapper (this will download weights the first time)
# If your llm_api.LLM expects device param, pass "cuda" or "cpu"
llm = LLM(device="cuda" if torch.cuda.is_available() else "cpu")
print("LLM object created.")
# Out:
# ============================================================
# ✅ Using GPU: Tesla T4 (14.7 GB VRAM)
# ============================================================
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# LLM object created.

# %%
# Paths to config files (adjust if names differ)
CRITERIA_PATH = os.path.join(PROJECT_DIR, "criteria.yml")
GLOSSARY_PATH = os.path.join(PROJECT_DIR, "domain_glossary.csv")
TRACE_DIR = os.path.join(PROJECT_DIR, "results", "agent_traces")
RESULTS_FILE = os.path.join(PROJECT_DIR, "results", "results_agent_judge.json")

os.makedirs(TRACE_DIR, exist_ok=True)
os.makedirs(os.path.dirname(RESULTS_FILE), exist_ok=True)

memory = Memory(criteria_path=CRITERIA_PATH, glossary_path=GLOSSARY_PATH)
tools = Toolset(glossary_path=GLOSSARY_PATH)
logger = AgentLogger(TRACE_DIR)

# Planner signature we used: Planner(memory, tools, logger, device)
planner = planner.Planner(memory=memory, tools=tools, logger=logger, device="cuda" if torch.cuda.is_available() else "cpu") # Corrected instantiation

print("Agent components initialized.")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/550 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ============================================================
# ✅ Using GPU: Tesla T4 (14.7 GB VRAM)
# ============================================================
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Agent components initialized.

# %% [markdown]
# ## Evaluate Dataset

# %%
# Set the Dataset
import pandas as pd
import os

dataset_path = os.path.join(PROJECT_DIR, "LLM_dataset.csv")

dataset = []
if os.path.exists(dataset_path):
    try:
        df = pd.read_csv(dataset_path, encoding='utf-8')

        # Convert DataFrame to list of dictionaries using your specific headers
        for _, row in df.iterrows():
            dataset.append({
                "source": row['Source Text (English)'],
                "translation": row['Target Text (Filipino)'],
                "human_score": row['Final Score                          (1 - lowest, 5 - highest)']
            })

        print(f"Loaded {len(dataset)} examples from dataset.csv")
    except Exception as e:
        print(f"Error loading CSV: {e}")
        # Fallback to sample data
        dataset = [
            {
                "source": "The Department of Health announced a new vaccine rollout.",
                "translation": "Inanunsyo ng Kagawaran ng Kalusugan ang bagong programa ng pagbabakuna.",
                "human_score": 5
            },
            {
                "source": "Blood pressure must be monitored regularly for patients with diabetes.",
                "translation": "Ang presyon ng dugo ay dapat regular na sinusuri para sa mga pasyenteng may diabetes.",
                "human_score": 3
            }
        ]
        print("Using fallback sample dataset:", len(dataset))
else:
    # Fallback sample data
    dataset = [
        {
            "source": "The Department of Health announced a new vaccine rollout.",
            "translation": "Inanunsyo ng Kagawaran ng Kalusugan ang bagong programa ng pagbabakuna.",
            "human_score": 5
        },
        {
            "source": "Blood pressure must be monitored regularly for patients with diabetes.",
            "translation": "Ang presyon ng dugo ay dapat regular na sinusuri para sa mga pasyenteng may diabetes.",
            "human_score": 3
        }
    ]
    print("Using fallback sample dataset:", len(dataset))
# Out:
# Error loading CSV: name 'pd' is not defined
# Using fallback sample dataset: 2

# %%
# Run the Agentic AI judge on the Dataset
from tqdm import tqdm
import json

def run_and_save(dataset, planner, out_file):
    with open(out_file, 'a', encoding='utf-8') as fout:
        for i, sample in enumerate(tqdm(dataset, desc="Evaluating")):
            try:
                result = planner.evaluate(sample)
            except Exception as e:
                # graceful fallback
                result = {
                    "error": str(e),
                    "criteria_scores": {},
                    "raw_sum": 0,
                    "overall_score": 1,
                    "label": "error",
                    "explanation": {}
                }
            # enrich result with identifiers if present
            result_meta = {
                "index": i,
                "source": sample.get("source"),
                "translation": sample.get("translation"),
                "reference": sample.get("reference", None),
                "human_score": sample.get("human_score", None),
                "result": result
            }
            fout.write(json.dumps(result_meta, ensure_ascii=False) + "\n")
    print("Saved results to", out_file)

run_and_save(dataset, planner, RESULTS_FILE)
# Out:
# Evaluating:   0%|          | 0/64 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   2%|▏         | 1/64 [02:06<2:12:47, 126.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   3%|▎         | 2/64 [03:49<1:56:22, 112.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   5%|▍         | 3/64 [05:24<1:46:15, 104.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   6%|▋         | 4/64 [06:56<1:39:40, 99.67s/it] The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   8%|▊         | 5/64 [09:07<1:49:08, 110.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:   9%|▉         | 6/64 [10:46<1:43:24, 106.98s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  11%|█         | 7/64 [12:51<1:47:04, 112.71s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  12%|█▎        | 8/64 [14:33<1:42:06, 109.41s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  14%|█▍        | 9/64 [16:12<1:37:12, 106.04s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  16%|█▌        | 10/64 [18:20<1:41:32, 112.83s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  17%|█▋        | 11/64 [20:38<1:46:24, 120.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  19%|█▉        | 12/64 [22:30<1:42:22, 118.12s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  20%|██        | 13/64 [24:11<1:35:56, 112.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  22%|██▏       | 14/64 [25:45<1:29:15, 107.11s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  23%|██▎       | 15/64 [27:19<1:24:21, 103.30s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  25%|██▌       | 16/64 [29:08<1:23:52, 104.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  27%|██▋       | 17/64 [30:44<1:20:05, 102.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  30%|██▉       | 19/64 [32:19<57:38, 76.85s/it]   The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  31%|███▏      | 20/64 [34:11<1:02:48, 85.65s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  33%|███▎      | 21/64 [35:56<1:05:01, 90.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  34%|███▍      | 22/64 [37:50<1:07:54, 97.02s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  38%|███▊      | 24/64 [39:41<52:33, 78.85s/it]  The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  39%|███▉      | 25/64 [41:27<55:30, 85.40s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  41%|████      | 26/64 [43:07<56:25, 89.08s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  42%|████▏     | 27/64 [44:50<57:17, 92.90s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  45%|████▌     | 29/64 [46:47<45:24, 77.85s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  47%|████▋     | 30/64 [48:34<48:00, 84.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  48%|████▊     | 31/64 [50:15<48:51, 88.84s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  50%|█████     | 32/64 [51:47<47:53, 89.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  53%|█████▎    | 34/64 [53:42<37:58, 75.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  55%|█████▍    | 35/64 [56:06<44:20, 91.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  56%|█████▋    | 36/64 [58:19<47:43, 102.28s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  58%|█████▊    | 37/64 [59:45<44:05, 97.97s/it] The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  59%|█████▉    | 38/64 [1:01:23<42:26, 97.96s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  61%|██████    | 39/64 [1:03:25<43:40, 104.82s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  62%|██████▎   | 40/64 [1:05:03<41:05, 102.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  64%|██████▍   | 41/64 [1:06:41<38:50, 101.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  66%|██████▌   | 42/64 [1:08:47<39:48, 108.57s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  67%|██████▋   | 43/64 [1:10:36<38:00, 108.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  69%|██████▉   | 44/64 [1:12:25<36:18, 108.93s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  70%|███████   | 45/64 [1:13:52<32:24, 102.35s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  73%|███████▎  | 47/64 [1:15:37<22:32, 79.53s/it] The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  75%|███████▌  | 48/64 [1:17:44<24:17, 91.07s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  77%|███████▋  | 49/64 [1:19:37<24:13, 96.87s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  78%|███████▊  | 50/64 [1:21:36<23:59, 102.80s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  81%|████████▏ | 52/64 [1:23:20<16:08, 80.67s/it] The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  83%|████████▎ | 53/64 [1:24:49<15:10, 82.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  84%|████████▍ | 54/64 [1:26:20<14:06, 84.61s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  86%|████████▌ | 55/64 [1:27:52<12:59, 86.64s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  89%|████████▉ | 57/64 [1:30:07<09:08, 78.42s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  91%|█████████ | 58/64 [1:31:42<08:14, 82.43s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  92%|█████████▏| 59/64 [1:33:34<07:28, 89.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  94%|█████████▍| 60/64 [1:35:59<06:57, 104.47s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  95%|█████████▌| 61/64 [1:37:33<05:04, 101.44s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  97%|█████████▋| 62/64 [1:39:09<03:20, 100.01s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating:  98%|█████████▊| 63/64 [1:40:59<01:42, 102.99s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating: 100%|██████████| 64/64 [1:43:09<00:00, 96.71s/it]
# Saved results to /content/drive/MyDrive/LLM_Project/results/results_agent_judge.json

# %%
# Calculate Spearman's Rho
import json, math
from scipy.stats import spearmanr

RESULTS_FILE = "/content/drive/MyDrive/LLM_Project/results/results_agent_judge.json"

llm_scores = []
human_scores = []

with open(RESULTS_FILE, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        entry = json.loads(line)
        human = entry.get("human_score")
        # print(human)
        model_out = entry.get("result", {})
        # print(model_out)
        # print(model_out.get("overall_score"))
        overall = model_out.get("overall_score")
        if human is not None and overall is not None:
            human_scores.append(float(human))
            llm_scores.append(float(overall))

def is_nan(x):
    try:
        # Check for float nan
        return math.isnan(float(x))
    except:
        # If conversion fails, maybe string 'nan' or other invalid value
        return str(x).lower() == 'nan'

filtered_pairs = [(h, l) for h, l in zip(human_scores, llm_scores) if not (is_nan(h) or is_nan(l))]

if len(filtered_pairs) >= 2:
    human_scores_clean, llm_scores_clean = zip(*filtered_pairs)
    human_scores_clean = list(human_scores_clean)
    llm_scores_clean = list(llm_scores_clean)
    # Now run your correlation
    rho, pval = spearmanr(human_scores_clean, llm_scores_clean)
    print(f"Spearman rho: {rho:.4f}, p-value: {pval:.4g} (N={len(human_scores_clean)})")
else:
    print("Not enough valid data points after removing NaNs.")
# Out:
# Spearman rho: -0.0678, p-value: 0.6165 (N=57)

# %%
# Check Explanation
import json
import math

missing_expl = []
with open(RESULTS_FILE, 'r', encoding='utf-8') as f:
    for line in f:
        entry = json.loads(line)
        source = entry.get("source")

        # Skip if source is nan (float nan or string "nan")
        if source is None:
            continue
        if isinstance(source, float) and math.isnan(source):
            continue
        if isinstance(source, str) and source.strip().lower() == "nan":
            continue

        res = entry.get("result", {})
        expl = res.get("explanation", {})
        expected_keys = {"accuracy", "fluency", "coherence", "cultural_appropriateness", "guideline_adherence", "completeness"}
        missing = expected_keys - set(expl.keys())
        if missing:
            missing_expl.append({"index": entry.get("index"), "missing": list(missing)})

print("Number of entries missing some criterion explanations:", len(missing_expl))
print(missing_expl[:10])
# Out:
# Number of entries missing some criterion explanations: 0
# []

# %%
# Print JSON Output
import json

try:
    with open(RESULTS_FILE, 'r', encoding='utf-8') as f:
        for line in f:
            # Load each line as JSON and pretty print it
            entry = json.loads(line)
            print(json.dumps(entry, ensure_ascii=False, indent=4))
            print("-" * 20) # Add a separator for clarity
except FileNotFoundError:
    print(f"Error: The file {RESULTS_FILE} was not found.")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
# Out:
# {
#     "index": 0,
#     "source": "The children laughed and played under the afternoon sun.",
#     "translation": "Ang mga bata ay nagtawanan at naglaro sa ilalim ng hapon na araw.",
#     "reference": null,
#     "human_score": 4.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 3,
#         "overall_score": 3,
#         "label": "good",
#         "explanation": {
#             "accuracy": "While the translation captures the main action (laughing and playing), it lacks specific details such as the time of day ('afternoon') and the setting ('under the sun'). These elements are crucial for conveying the full meaning of the original sentence.",
#             "fluency": "While the translation is correct and natural, it could benefit from a slight adjustment to improve its idiomatic flow without compromising its grammatical correctness.",
#             "coherence": "While there is a minor difference in the time of day mentioned, the core meaning and logical flow of the sentence are maintained, earning a score of 1.",
#             "cultural_appropriateness": "While the translation is accurate and grammatically correct, it lacks culturally appropriate phrasing and does not include formalities or honorifics that would be expected in a general context.",
#             "guideline_adherence": "While there is a slight deviation from the exact phrasing of the source text, the translation correctly uses Filipino terms and follows the natural flow of the language, thus meeting the guideline_adherence criterion.",
#             "completeness": "The translation omits the crucial word 'under' and does not include the specific time of day ('afternoon'), which are essential elements of the source text."
#         }
#     }
# }
# --------------------
# {
#     "index": 1,
#     "source": "She took a break to gather her thoughts.",
#     "translation": "Nagpahinga siya para mag-isip-isip.",
#     "reference": null,
#     "human_score": 4.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to capture the precise meaning and intent of the original sentence, making it inaccurate.",
#             "fluency": "Although the translation is technically correct and follows natural Filipino syntax, it uses a term ('pahinga') that might not be immediately understood as meaning a break from work or activities. This slight deviation from common usage slightly reduces its fluency.",
#             "coherence": "The translation lacks clarity in conveying the specific action of taking a break to gather thoughts, disrupting the logical flow of the original sentence.",
#             "cultural_appropriateness": "While the translation is generally appropriate and formal, it does not fully capture the common Filipino expression for taking a break, which is 'napahinga.' This omission slightly reduces its cultural appropriateness.",
#             "guideline_adherence": "While the core meaning is preserved, the choice of 'isip-isip' instead of 'mag-isip' or another term for gathering thoughts does not adhere to standard Filipino language conventions for this specific context.",
#             "completeness": "While the core meaning is preserved, the translation lacks specific details from the source text, which could affect the completeness of the translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 2,
#     "source": "The algorithm efficiently identifies patterns in large datasets.",
#     "translation": "Mabisang kinikilala ng algoritmo ang mga pattern sa malalaking dataset.",
#     "reference": null,
#     "human_score": 3.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "While the translation captures the essence of the source text, it fails to convey the specific quality of efficiency that is present in the English version.",
#             "fluency": "While the translation is mostly fluent and natural, it lacks the precise modifier 'bisan' which could have improved its accuracy in conveying the source text's meaning.",
#             "coherence": "While the translation captures the essence of the source text, it fails to maintain a coherent flow due to the missing word 'bisan' and the slight mismatch in phrasing.",
#             "cultural_appropriateness": "The translation is not sufficiently formal and does not use culturally appropriate phrasing, which is crucial for conveying the intended message appropriately in a Filipino context.",
#             "guideline_adherence": "The translation uses correct domain-specific terms and adheres to the style rules for technical writing, as evidenced by the tool output and the context of the source text.",
#             "completeness": "The translation lacks the critical word 'efficiently', which is necessary to convey the full meaning of the original sentence. This omission affects the accuracy and completeness of the translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 3,
#     "source": "Data normalization helps improve model performance.",
#     "translation": "Tumutulong sa pagpabuti ng model ang normalisasyon ng datos",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 1,
#             "fluency": 1,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 3,
#         "overall_score": 3,
#         "label": "good",
#         "explanation": {
#             "accuracy": "While there is a slight structural difference, the core meaning and intent of the source text are accurately conveyed in the Filipino translation.",
#             "fluency": "While the translation is accurate and fluent, it slightly deviates from the original meaning of the English sentence. However, given the context and the overall fluency, a score of 1 is appropriate.",
#             "coherence": "The translation disrupts the logical flow and meaning of the original sentence, making it difficult to follow the intended message.",
#             "cultural_appropriateness": "The translation is accurate but fails to incorporate Filipino cultural elements or idioms, making it less culturally appropriate.",
#             "guideline_adherence": "While the sentence structure differs slightly from the source text, the use of correct terminology ('normalization of data') and adherence to technical writing style are sufficient to meet the criterion.",
#             "completeness": "The translation is missing the key word 'helps', which is essential for conveying the complete meaning of the original sentence. This omission results in an incomplete translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 4,
#     "source": "alam mo ma'am masaya naman topics natin sa philosophy inaantok lang talaga ko kasi ikaw nagdidiscuss",
#     "translation": "You know, ma'am, we have a lot of fun philosophy topics. I'm just really sleepy in what you're discussing.",
#     "reference": null,
#     "human_score": 4.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to accurately represent the source text's meaning and intent, making it an inaccurate translation.",
#             "fluency": "The translation fails to meet the criterion of being grammatically correct, natural, and idiomatic for a native speaker due to structural issues and awkward phrasing.",
#             "coherence": "The translation lacks coherence as it mixes ideas from the source text with unrelated thoughts, disrupting the logical flow and context.",
#             "cultural_appropriateness": "The translation fails to use appropriate Filipino cultural norms, idioms, and formality, making it unsuitable for a Filipino audience.",
#             "guideline_adherence": "The translation fails to use correct domain-specific terms and does not follow the expected style rules for a philosophical discussion.",
#             "completeness": "The translation lacks crucial parts of the original sentence, leading to an incomplete translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 5,
#     "source": "It's raining cats and dogs.",
#     "translation": "Umuulan ng pusa at aso.",
#     "reference": null,
#     "human_score": 1.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation is inaccurate as it does not correctly represent the idiomatic expression of heavy rain in English.",
#             "fluency": "Although the translation is grammatically correct, it fails to accurately convey the idiomatic meaning of the source text, making it unnatural for a native speaker.",
#             "coherence": "The translation fails to preserve the metaphorical meaning and the logical structure of the source text.",
#             "cultural_appropriateness": "The translation does not accurately represent the cultural idiom of 'it's raining cats and dogs' in Filipino, failing to capture the intended meaning and cultural nuances.",
#             "guideline_adherence": "The translation uses a term ('pusa') that is not commonly used in Filipino for animals, and there is no specific domain guide for idiomatic expressions that would require adherence to a particular term.",
#             "completeness": "The translation fails to convey the idiomatic meaning of 'raining cats and dogs,' which is crucial to the original expression. Therefore, it scores 0 for not meeting the completeness criterion."
#         }
#     }
# }
# --------------------
# {
#     "index": 6,
#     "source": "The party of the first part shall not be held liable for any unforeseen damages.",
#     "translation": "Ang partido ng unang bahagi ay hindi mananagot para sa anumang hindi inaasahang pinsala.",
#     "reference": null,
#     "human_score": 4.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation is inaccurate and fails to convey the legal meaning and implications of the source text.",
#             "fluency": "The translation lacks accuracy and naturalness, failing to effectively communicate the original meaning in idiomatic Filipino.",
#             "coherence": "The translation fails to preserve the logical structure and meaning of the original sentence, making it difficult to understand the intended legal liability.",
#             "cultural_appropriateness": "The translation lacks accuracy in legal terminology and does not follow Filipino linguistic conventions, failing to meet the criterion of cultural appropriateness.",
#             "guideline_adherence": "The translation lacks adherence to legal terminology and style conventions, using colloquial terms that do not match the formal nature of the original English text.",
#             "completeness": "The translation fails to accurately represent all parts of the source text, particularly the critical concepts of liability and unforeseen damages, indicating an incomplete and possibly inaccurate translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 7,
#     "source": "Thank you for coming to the event.",
#     "translation": "Salamat sa pagpunta sa kaganapan.",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "While the translation captures the basic meaning, it lacks precision in conveying all nuances, as indicated by the tool output suggesting low semantic similarity.",
#             "fluency": "While the translation is grammatically correct, it lacks fluency due to its literal nature and could be improved to sound more natural.",
#             "coherence": "The translation lacks the logical flow and structure of the original sentence, making it difficult to follow the intended meaning.",
#             "cultural_appropriateness": "The translation fails to use the required polite form markers, which is essential for cultural appropriateness in Filipino communication.",
#             "guideline_adherence": "The translation correctly uses appropriate Filipino terms and follows the common style rules for expressing gratitude and attending events.",
#             "completeness": "While the translation is accurate in conveying the main idea, it omits the specific mention of 'the event,' which could alter the precise meaning of the original sentence."
#         }
#     }
# }
# --------------------
# {
#     "index": 8,
#     "source": "Despite her exhaustion, she finished the report before the deadline.",
#     "translation": "Sa kabila ng kanyang pagod, natapos niya ang ulat bago ang deadline.",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation preserves the main idea but fails to convey a key detail about her exhaustion, which is essential to understanding the full context of her actions.",
#             "fluency": "While the translation is mostly correct and fluent, the word order needs adjustment for perfect fluency.",
#             "coherence": "While there is a minor difference in phrasing, the core meaning and logical flow of the sentence are preserved, earning a score of 1.",
#             "cultural_appropriateness": "While the translation is accurate in meaning, it lacks the necessary formalities that would be expected in a professional context, which is why it receives a score of 0.",
#             "guideline_adherence": "The translation uses correct Filipino grammar and sentence structure but fails to use the correct term for 'report' in the context of deadlines and work completion.",
#             "completeness": "The translation lacks the context that explains why she finished the report early, making it incomplete."
#         }
#     }
# }
# --------------------
# {
#     "index": 9,
#     "source": "That designer bag costs an arm and a leg.",
#     "translation": "Napakamahal ng designer bag na 'yan.",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "Although the translation conveys the basic idea of something being very expensive, it fails to capture the specific idiomatic meaning of 'an arm and a leg.' This results in a score of 0 as the criterion requires the translation to accurately convey all key information and nuances.",
#             "fluency": "Although the translation is grammatically correct, it fails to convey the idiomatic expression of the original sentence, making it less fluent.",
#             "coherence": "The translation is faithful to the meaning but fails to preserve the metaphorical expression and the overall logical structure of the source text.",
#             "cultural_appropriateness": "Although the translation is grammatically correct and avoids cultural insensitivity, it does not capture the exact cultural nuance of the original English idiom.",
#             "guideline_adherence": "The translation uses appropriate Filipino terminology and maintains the idiomatic expression consistent with the source text's style.",
#             "completeness": "The translation lacks the idiomatic expression 'an arm and a leg,' which is crucial for conveying the full meaning of the original sentence. This omission means the translation is not complete."
#         }
#     }
# }
# --------------------
# {
#     "index": 10,
#     "source": "I didn’t want to go to the dentist, but I had to bite the bullet and get it over with.",
#     "translation": "Ayoko sanang pumunta sa dentista, pero kailangan kong tiisin ito para matapos na.",
#     "reference": null,
#     "human_score": 4.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "While the core message is preserved, the translation fails to convey the intended metaphorical meaning of 'biting the bullet,' leading to a significant alteration of the original intent.",
#             "fluency": "While the translation is close to being perfect, the use of 'tiisin ito' is not idiomatic Filipino. However, the text is still free of major grammatical errors and maintains natural flow.",
#             "coherence": "While the core message is preserved, the translation could be more natural and coherent with slight adjustments.",
#             "cultural_appropriateness": "The translation fails to use culturally appropriate phrasing and idioms, which is essential for conveying the intended meaning and cultural context.",
#             "guideline_adherence": "The translation uses incorrect dental terminology, failing to adhere to domain-specific style guidelines.",
#             "completeness": "The translation misses out on conveying the full intention behind the speaker's reluctance to go to the dentist, as indicated by the phrase 'bite the bullet and get it over with.' This omission impacts the completeness of the translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 11,
#     "source": "Mark accidentally let the cat out of the bag about the surprise trip.",
#     "translation": "Hindi sinasadyang nailabas ni Mark ang pusa mula sa maleta tungkol sa surprise trip.",
#     "reference": null,
#     "human_score": 3.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to accurately convey the meaning and intent of the original text, particularly regarding the revelation of a secret and the nature of the trip being a surprise.",
#             "fluency": "The translation fails to capture the essence of the original sentence and uses inappropriate words and phrases, making it difficult for a native speaker to understand the intended meaning.",
#             "coherence": "The translation fails to preserve the intended meaning and logical structure of the original sentence due to inaccurate translation and unclear references.",
#             "cultural_appropriateness": "The translation misses the opportunity to use a more culturally appropriate idiom and fails to reflect the typical Filipino understanding of a 'surprise trip.'",
#             "guideline_adherence": "The translation uses incorrect terminology ('maleta' instead of 'bag') and does not follow the specific style guide for expressing the concept of 'letting something out.'",
#             "completeness": "The translation lacks crucial elements from the source text, making it incomplete."
#         }
#     }
# }
# --------------------
# {
#     "index": 12,
#     "source": "I won’t be able to attend the meeting later because I’m feeling under the weather.",
#     "translation": "Hindi ako makakadalo sa meeting mamaya dahil masama ang pakiramdam ko.",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation preserves the general meaning but fails to accurately capture the specific figurative expression 'under the weather,' leading to a loss of nuance.",
#             "fluency": "While not entirely idiomatic, the translation is grammatically correct and effectively communicates the meaning, earning a score of 1.",
#             "coherence": "Although there is a slight deviation from a common Filipino expression, the overall coherence is maintained as the translation adheres to the logical flow and structure of the source text.",
#             "cultural_appropriateness": "The translation lacks the necessary cultural appropriateness and formalities expected in Filipino language usage.",
#             "guideline_adherence": "The translation uses a common Filipino expression but incorrectly translates the medical condition 'feeling under the weather,' which is not adhering to domain-specific style guidelines.",
#             "completeness": "The translation lacks critical information about the inability to attend the meeting and the reason behind it, failing to meet the criterion of completeness."
#         }
#     }
# }
# --------------------
# {
#     "index": 13,
#     "source": "Darkness is not heresy. It lies within us all.",
#     "translation": "Hindi kasalanan ang kadiliman. Nagsisinungaling ito sa loob natin.",
#     "reference": null,
#     "human_score": 2.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 1,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "Although the main idea is conveyed correctly, the translation fails to preserve the full nuance of the original statement, particularly the sense of darkness being inherent or universal.",
#             "fluency": "While the translation avoids major grammatical errors, it contains some potential issues in terms of idiomatic expression that might slightly disrupt readability.",
#             "coherence": "While the first part of the sentence is correctly translated, the second part lacks a direct equivalent that maintains the same meaning and logical flow.",
#             "cultural_appropriateness": "The translation is culturally appropriate and avoids any offensive expressions. However, it lacks some colloquial elements that might make it sound more natural in Filipino.",
#             "guideline_adherence": "The translation uses appropriate Filipino vocabulary but lacks adherence to any specific domain-specific style guides, terminology, or conventions.",
#             "completeness": "The translation misses the second part of the source text, which is crucial for conveying the full meaning. Therefore, the translation fails to meet the completeness criterion."
#         }
#     }
# }
# --------------------
# {
#     "index": 14,
#     "source": "This would be easier if blood came in more colours.",
#     "translation": "Ito ay magiging mas madali kung ang dugo ay dumating sa mas maraming kulay.",
#     "reference": null,
#     "human_score": 2.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 1,
#             "cultural_appropriateness": 1,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to accurately represent the original meaning due to mismatches in vocabulary and sentence structure.",
#             "fluency": "While the translation is grammatically correct, it does not accurately convey the idiomatic meaning of the source text.",
#             "coherence": "While there is a slight deviation in the use of words, the translation effectively conveys the same meaning and maintains logical coherence.",
#             "cultural_appropriateness": "The translation is culturally appropriate and uses proper Filipino phrasing and honorifics. It accurately conveys the meaning of the source text while maintaining a respectful and natural tone.",
#             "guideline_adherence": "Although the translation is technically correct, it does not use a natural Filipino expression for the concept of 'more colors', which is a key aspect of the domain-specific style guide.",
#             "completeness": "The translation misses the implication of a hypothetical scenario and lacks the word 'would be', indicating that not all parts of the source text are accurately translated."
#         }
#     }
# }
# --------------------
# {
#     "index": 15,
#     "source": "This guy right here is Shadow, and he's kinda my biggest rival. He's also a real buzz-kill.",
#     "translation": "Ang lalaking ito dito ay si Shadow, at siya ang aking pinakamalaking karibal. Isa rin siyang totoong buzz-kill.",
#     "reference": null,
#     "human_score": 1.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 1,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 4,
#         "overall_score": 4,
#         "label": "good",
#         "explanation": {
#             "accuracy": "Although the translation preserves the main idea and relationship between the characters, it does not accurately convey the intensity and negativity implied by 'real buzz-kill', which is crucial for the full meaning of the original text.",
#             "fluency": "While the translation is mostly fluent and grammatically correct, the idiomatic expression for 'buzz-kill' could be improved for better naturalness.",
#             "coherence": "While the translation is mostly coherent, the omission of key phrases like 'this guy right here' and the lack of a direct translation for 'buzz-kill' slightly disrupts the flow and completeness of the sentence.",
#             "cultural_appropriateness": "While the translation does not use a Filipino-specific idiom for 'buzz-kill,' it still conveys the meaning appropriately and adheres to Filipino cultural norms and idioms.",
#             "guideline_adherence": "The translation uses correct Filipino equivalents for the terms and maintains the style of the original text, adhering to the guideline_adherence criterion.",
#             "completeness": "The translation misses out on the part about Shadow being a 'real buzz-kill', which is crucial for understanding his nature as a rival. This omission affects the completeness of the translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 16,
#     "source": "Stealth is not your thing. But it's adorable you're willing to try.",
#     "translation": "Ang pagnanakaw ay hindi bagay sa iyo. Ngunit ito ay kaibig-ibig na handa kang subukan.",
#     "reference": null,
#     "human_score": 1.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 1,
#             "cultural_appropriateness": 1,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation lacks accuracy in both the core concept and the emotional tone, failing to properly represent the source text's meaning and intent.",
#             "fluency": "While the translation avoids major grammatical errors, it misinterprets the meaning of 'stealth' and uses a less appropriate term, resulting in an unnatural phrasing that disrupts readability.",
#             "coherence": "The translation effectively preserves the logical flow and context of the source text, maintaining coherence.",
#             "cultural_appropriateness": "The translation appropriately conveys the meaning while using culturally sensitive language and idioms, thus earning a score of 1.",
#             "guideline_adherence": "Although the translation is faithful to the source text, it does not adhere to any specific domain-specific style guides or conventions, as no such guidelines were mentioned.",
#             "completeness": "The translation lacks the key term 'stealth' and omits the context about willingness to try, making it incomplete."
#         }
#     }
# }
# --------------------
# {
#     "index": 17,
#     "source": NaN,
#     "translation": NaN,
#     "reference": null,
#     "human_score": NaN,
#     "result": {
#         "error": "'float' object is not subscriptable",
#         "criteria_scores": {},
#         "raw_sum": 0,
#         "overall_score": 1,
#         "label": "error",
#         "explanation": {}
#     }
# }
# --------------------
# {
#     "index": 18,
#     "source": "Cheddar cheese got its name from a village in what country?",
#     "translation": "Ang nayon na pinagkuhanan ng pangalan ng cheddar cheese ay nasaang bansa?",
#     "reference": null,
#     "human_score": 3.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation lacks accuracy in conveying the full meaning and intent of the source text, particularly regarding the country aspect and the specific phrasing of the question.",
#             "fluency": "The translation has structural and syntactical issues that make it less natural and idiomatic for a Filipino native speaker.",
#             "coherence": "The translation is disjointed and unclear, failing to maintain the logical flow and context of the original question.",
#             "cultural_appropriateness": "The translation is not culturally appropriate as it uses incorrect terminology and lacks proper formality. It does not respect Filipino cultural norms and idioms.",
#             "guideline_adherence": "While the translation uses correct terms and follows general style rules, it incorrectly attributes the naming of cheddar cheese to a village, which is not consistent with the actual history of the cheese. This deviation from the specific domain knowledge prevents full adherence to the criterion.",
#             "completeness": "The translation is incomplete as it fails to accurately represent all parts of the source text, particularly the mention of a village and the structure of the question."
#         }
#     }
# }
# --------------------
# {
#     "index": 19,
#     "source": "Which of the following tools is LEAST likely to be used in the process of creating a wood sculpture?",
#     "translation": "Alin sa mga sumusunod ang PINAKABIHIRANG ginagamit sa paggawa ng eskulturang kahoy?",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 1,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation deviates from the source text's meaning and intent, altering the core question and changing the focus from tools to items.",
#             "fluency": "While the translation avoids major grammatical errors, it contains several stylistic and syntactic issues that make it less than fluent for a native speaker.",
#             "coherence": "The translation is semantically close but lacks the necessary coherence due to the incorrect use of terminology and the disordered sentence structure.",
#             "cultural_appropriateness": "While there are some minor adjustments that could make the translation even more natural, the overall translation is culturally appropriate and conveys the intended meaning.",
#             "guideline_adherence": "The translation fails to use the correct domain-specific term and does not follow the appropriate style rules for the technical context.",
#             "completeness": "The translation misses a critical part of the original question, making it incomplete and potentially altering the meaning."
#         }
#     }
# }
# --------------------
# {
#     "index": 20,
#     "source": "With what would you use a \"wah-wah pedal?",
#     "translation": "Ano ang gagamitin mo ng \"wah-wah pedal?",
#     "reference": null,
#     "human_score": 1.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "While the translation captures the essence of the question, the score of 0.787 suggests there may be some minor inaccuracies or omissions, which does not meet the criterion's requirement for perfect accuracy.",
#             "fluency": "While the translation is grammatically correct and follows natural Filipino syntax, it lacks the idiomatic expression expected for a technical term like 'wah-wah pedal.'",
#             "coherence": "While the translation is accurate and maintains the logical structure, it does not perfectly match the specific phrasing of the reference translation. However, given the focus on coherence rather than exact wording, a score of 1 is appropriate.",
#             "cultural_appropriateness": "The translation is accurate but lacks the formal address 'po' and does not fully adhere to Filipino cultural norms.",
#             "guideline_adherence": "The translation fails to adhere to domain-specific terms as it uses a term ('wah-wah pedal') that is not commonly used in Filipino and may not be understood by the target audience.",
#             "completeness": "While the main idea is preserved, the omission of 'with' makes the translation slightly less complete as it could be interpreted as asking about the general usage of the pedal rather than a specific context."
#         }
#     }
# }
# --------------------
# {
#     "index": 21,
#     "source": "Which of the following dental topics is developmentally appropriate for toddlers?",
#     "translation": "Alin sa mga sumusunod na paksa sa ngipin ang angkop sa pag-unlad para sa mga paslit?",
#     "reference": null,
#     "human_score": 2.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to accurately represent the source text's meaning and intent, altering the core question and introducing ambiguity.",
#             "fluency": "The translation fails to meet the criterion of fluency due to structural issues and the use of less natural terms.",
#             "coherence": "The translation lacks coherence as it disrupts the logical flow and meaning of the original question.",
#             "cultural_appropriateness": "The translation lacks cultural appropriateness as it uses terms not commonly found in Filipino and does not follow proper Filipino sentence structure.",
#             "guideline_adherence": "The translation uses incorrect terms and does not follow domain-specific conventions, failing to accurately represent the source text in a way that adheres to the Filipino language and terminology used in the field of pediatric dentistry.",
#             "completeness": "The translation lacks key elements from the original sentence and does not provide a comprehensive translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 22,
#     "source": NaN,
#     "translation": NaN,
#     "reference": null,
#     "human_score": NaN,
#     "result": {
#         "error": "'float' object is not subscriptable",
#         "criteria_scores": {},
#         "raw_sum": 0,
#         "overall_score": 1,
#         "label": "error",
#         "explanation": {}
#     }
# }
# --------------------
# {
#     "index": 23,
#     "source": "The Bloons are back and better than ever! Get ready for a massive 3D tower defense game designed to give you hours and hours of the best strategy gaming available.",
#     "translation": "Ang Bloons ay bumalik at mas mahusay kaysa dati! Maghanda para sa isang napakalaking 3D tower defense na laro na idinisenyo upang bigyan ka ng mga oras at oras ng pinakamahusay na diskarte sa paglalaro na magagamit.",
#     "reference": null,
#     "human_score": 3.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to accurately convey all key information and nuances from the source text, particularly in terms of the game genre and its intended gameplay experience.",
#             "fluency": "While the translation is mostly correct and natural-sounding, there are small improvements needed to enhance its fluency.",
#             "coherence": "While the translation attempts to maintain the original meaning and structure, it lacks clarity and proper word order, disrupting the overall coherence.",
#             "cultural_appropriateness": "The translation fails to capture the cultural nuances and idiomatic expressions present in the original text, particularly regarding the term 'bloons' and the intensity of the comparison. These elements are crucial for maintaining the spirit and appeal of the original message.",
#             "guideline_adherence": "The translation maintains the style and tone of the original text while adhering to Filipino language conventions. It uses appropriate terms and structures that align with the gaming domain.",
#             "completeness": "The translation lacks crucial details about the game being a 3D tower defense and offering extended gameplay, which are significant parts of the original message."
#         }
#     }
# }
# --------------------
# {
#     "index": 24,
#     "source": "Sea of Thieves is a smash-hit pirate adventure game, offering the quintessential pirate experience of plundering lost treasures, intense battles, vanquishing sea monsters and more. Dive in with this revised edition of the game, which includes access to digital bonus media.",
#     "translation": "Ang Sea of Thieves ay isang smash-hit na pirate adventure game, na nag-aalok ng quintessential na karanasan sa pirata ng pagnanakaw sa mga nawawalang kayamanan, matinding labanan, pagtalo sa mga halimaw sa dagat at higit pa. Sumisid sa binagong edisyon ng larong ito, na kinabibilangan ng access sa digital bonus media.",
#     "reference": null,
#     "human_score": 2.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 1,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 4,
#         "overall_score": 4,
#         "label": "good",
#         "explanation": {
#             "accuracy": "While the translation preserves the general meaning and intent of the source text, it contains inaccuracies and omissions that impact the overall accuracy, warranting a score of 0.",
#             "fluency": "While not perfect, the translation is mostly fluent and natural, meeting the criteria for a good quality translation.",
#             "coherence": "While the translation is coherent and maintains the logical flow of the source text, there are slight disruptions due to minor word choices that could be improved for full coherence.",
#             "cultural_appropriateness": "While there is a slight deviation from a more formal term, the translation is otherwise culturally appropriate and adheres to Filipino linguistic conventions.",
#             "guideline_adherence": "The translation correctly uses gaming-related terminology and follows the style guide for the domain, despite minor deviations in terminology that are likely due to the nature of the source text.",
#             "completeness": "While the translation captures the essence of the source text, it fails to include the specific detail about the inclusion of digital bonus media, which is a crucial part of the original message. This omission means the translation cannot be considered complete."
#         }
#     }
# }
# --------------------
# {
#     "index": 25,
#     "source": "The Binding of Isaac: Rebirth is a randomly generated action RPG shooter with heavy Rogue-like elements. Following Isaac on his journey players will find bizarre treasures that change Isaac's form giving him super human abilities and enabling him to fight off droves of mysterious creatures, discover secrets and fight his way to safety.",
#     "translation": "Ang The Binding of Isaac: Rebirth ay isang random na nabuong action RPG shooter na may mabibigat na elementong parang Rogue. Kasunod ni Isaac sa kanyang paglalakbay, ang mga manlalaro ay makakahanap ng mga kakaibang kayamanan na nagpabago sa anyo ni Isaac na nagbibigay sa kanya ng sobrang mga kakayahan ng tao at nagbibigay-daan sa kanya upang labanan ang napakaraming mga misteryosong nilalang, tumuklas ng mga lihim at labanan ang kanyang daan patungo sa kaligtasan.",
#     "reference": null,
#     "human_score": 2.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to accurately convey all key information and nuances of the source text, particularly due to the omission of important titles and specific game mechanics.",
#             "fluency": "While the translation is mostly fluent and natural, it contains some minor issues with idiomatic expression. A more natural translation would use 'random na nabuo' instead of 'random na nabuong'. However, given the context and the lack of significant grammatical errors, the score is set at 1.",
#             "coherence": "While there are minor adjustments in phrasing that slightly disrupt the flow, the core ideas and structure of the original text are maintained, earning a score of 1.",
#             "cultural_appropriateness": "While the translation is generally appropriate, it includes some terms that may not be familiar or culturally aligned in Filipino gaming contexts, which slightly reduces its cultural appropriateness score.",
#             "guideline_adherence": "While the translation uses correct domain-specific terms, it contains inconsistencies and awkward phrasing that prevent it from fully adhering to the style guide and conventions of the gaming domain.",
#             "completeness": "The translation lacks certain key details from the original text, particularly regarding the game mechanics and specific elements like Isaac's abilities and enemies. This omission indicates that the translation is not complete."
#         }
#     }
# }
# --------------------
# {
#     "index": 26,
#     "source": "Welcome to a new world! In Monster Hunter: World, the latest installment in the series, you can enjoy the ultimate hunting experience, using everything at your disposal to hunt monsters in a new world teeming with surprises and excitement.",
#     "translation": "Maligayang pagdating sa isang bagong mundo! Sa Monster Hunter: World, ang pinakabagong installment sa serye, masisiyahan ka sa pinakahuling karanasan sa pangangaso, gamit ang lahat ng iyong makakaya upang manghuli ng mga halimaw sa isang bagong mundo na puno ng mga sorpresa at kaguluhan.",
#     "reference": null,
#     "human_score": 4.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 1,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 4,
#         "overall_score": 4,
#         "label": "good",
#         "explanation": {
#             "accuracy": "While the translation is accurate in conveying the main ideas, there are subtle differences in wording that prevent it from being a perfect match. Therefore, the score is 1.",
#             "fluency": "While not perfect, the translation is fluent and natural, meeting the criteria for being easily understood by a native speaker.",
#             "coherence": "While the translation is mostly coherent, it could be improved by more accurately conveying the specific elements of the hunting experience and the description of the new world.",
#             "cultural_appropriateness": "Although the translation is generally culturally appropriate, it could improve by using more refined expressions and idioms that better reflect Filipino cultural norms.",
#             "guideline_adherence": "The translation uses correct domain-specific terms and adheres to the style rules for the video game genre, as evidenced by the absence of any incorrect or missing terms in the tool output.",
#             "completeness": "The translation lacks crucial elements such as the game title and the series context, which are essential for understanding the full scope of the source text."
#         }
#     }
# }
# --------------------
# {
#     "index": 27,
#     "source": NaN,
#     "translation": NaN,
#     "reference": null,
#     "human_score": NaN,
#     "result": {
# ...
#             "fluency": "While the translation is mostly correct and fluent, it contains elements that are unnatural and could be improved for better fluency.",
#             "coherence": "Although there is a minor grammatical correction needed, the translation effectively conveys the logical flow and context of the original sentence.",
#             "cultural_appropriateness": "While the translation is generally appropriate, the use of 'non-fiction na libro' is not a standard Filipino expression and could be improved for better fluency and accuracy.",
#             "guideline_adherence": "While there is a minor grammatical error, the translation uses correct terminology and adheres to the style rules for describing a well-organized and clean book collection.",
#             "completeness": "The translation omits the specific type of books (non-fiction) and does not fully capture the implication that the collection is always well-organized and clean, which are key aspects of the original text."
#         }
#     }
# }
# --------------------
# {
#     "index": 55,
#     "source": NaN,
#     "translation": NaN,
#     "reference": null,
#     "human_score": NaN,
#     "result": {
#         "error": "'float' object is not subscriptable",
#         "criteria_scores": {},
#         "raw_sum": 0,
#         "overall_score": 1,
#         "label": "error",
#         "explanation": {}
#     }
# }
# --------------------
# {
#     "index": 56,
#     "source": "Taking crazy things seriously is a serious waste of time.",
#     "translation": "Ang pagseseryoso ng mga bagay na baliw ay isang seryosong pag-aaksaya ng oras.",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation fails to capture the essence of the source text, leading to a misunderstanding of its meaning.",
#             "fluency": "The translation lacks the natural flow and idiomatic expression necessary for fluency, despite being grammatically correct.",
#             "coherence": "The translation lacks coherence due to the inaccurate and disjointed nature of the sentence structure, making it hard to understand the intended message.",
#             "cultural_appropriateness": "The translation fails to accurately convey the cultural and linguistic nuances of the original sentence, particularly in terms of seriousness and idiomatic expression.",
#             "guideline_adherence": "The translation uses a term that is not commonly used in Filipino for the specific concept, making it inconsistent with the chosen domain's style and terminology.",
#             "completeness": "The translation fails to convey the full meaning of the source text due to the omission of the 'crazy' aspect, leading to an inaccurate representation."
#         }
#     }
# }
# --------------------
# {
#     "index": 57,
#     "source": "Things outside you are projections of what’s inside you, and what’s inside you is a projection of what’s outside.",
#     "translation": "Ang mga bagay sa labas mo ay salamin ng nasa loob mo, at ang nasa loob mo ay salamin ng nasa labas.",
#     "reference": null,
#     "human_score": 3.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "While the general idea is conveyed, the translation lacks accuracy due to grammatical errors and inappropriate word choices, which alter the intended meaning.",
#             "fluency": "Although the translation is grammatically correct, it fails to accurately represent the meaning of the original text due to the mismatch in the concept of 'projections' being both from inside to outside and vice versa.",
#             "coherence": "While the translation attempts to maintain coherence, the use of 'salamin' instead of 'projection' and the slight difference in sentence structure disrupt the logical flow and meaning of the original text.",
#             "cultural_appropriateness": "The translation uses a term ('salamin') that is not commonly used in Filipino to describe projections or reflections, which may be considered culturally inappropriate. It also does not reflect Filipino cultural norms, idioms, formality, and sensitivities.",
#             "guideline_adherence": "While the translation does not strictly adhere to any specific domain-specific style guide, it maintains the core meaning and structure of the source text while using appropriate Filipino terminology.",
#             "completeness": "The translation fails to include the second half of the source text, which is crucial for conveying the full meaning of the statement. As a result, the translation is considered incomplete."
#         }
#     }
# }
# --------------------
# {
#     "index": 58,
#     "source": "Some men are born mediocre, some men achieve mediocrity, and some men have mediocrity thrust upon them.",
#     "translation": "May ilang lalaking ipinanganak na katamtaman, may ilang nakakamit ang pagiging karaniwan, at may ilan na ipinipilit na lamang sa kanila ang pagiging ganoon.",
#     "reference": null,
#     "human_score": 4.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation misses several key nuances and specific phrasing of the original sentence, leading to an overall loss of accuracy.",
#             "fluency": "While the translation is mostly correct and natural, it contains some slight adjustments needed for perfect fluency.",
#             "coherence": "Although there is a minor grammatical adjustment needed, the translation effectively preserves the logical flow and structure of the original text, earning a score of 1.",
#             "cultural_appropriateness": "While the translation is culturally appropriate and uses idiomatic expressions, it lacks the necessary formalities that could be expected in certain contexts.",
#             "guideline_adherence": "The translation is faithful to the source text but lacks adherence to any specific domain-specific style guides, terminology, or conventions as indicated by the provided tool output.",
#             "completeness": "The translation misses key elements from the source text, particularly the descriptions of achieving mediocrity and having mediocrity thrust upon one, which significantly impacts the overall completeness of the translation."
#         }
#     }
# }
# --------------------
# {
#     "index": 59,
#     "source": "Mother died today. Or maybe yesterday; I can't be sure.",
#     "translation": "Sumakabilang-buhay si Inay ngayong araw. O baka kahapon; medyo nalilito na ako.",
#     "reference": null,
#     "human_score": 2.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation misses the key nuance of uncertainty in the source text and does not fully capture the intended meaning.",
#             "fluency": "While the translation avoids obvious grammatical mistakes, it contains phrases that are less natural and idiomatic for Filipino speakers, which impacts its fluency.",
#             "coherence": "The translation lacks coherence due to incorrect phrasing and altered sentence structure, disrupting the logical flow and context of the original text.",
#             "cultural_appropriateness": "The translation fails to appropriately convey the cultural sensitivity and formality required for such a serious topic as the death of a mother.",
#             "guideline_adherence": "The translation fails to use correct terminologies specific to the English source text, despite following Filipino language structure and grammar.",
#             "completeness": "The translation omits the crucial element of uncertainty regarding the timing of Mother's death, which significantly impacts the meaning of the original sentence."
#         }
#     }
# }
# --------------------
# {
#     "index": 60,
#     "source": "The wave returns to the ocean, where it came from, and where it's supposed to be.",
#     "translation": "Bumabalik ang alon sa karagatan, kung saan ito nanggaling, at kung saan ito dapat nasa.",
#     "reference": null,
#     "human_score": 2.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 1,
#             "cultural_appropriateness": 1,
#             "guideline_adherence": 1,
#             "completeness": 0
#         },
#         "raw_sum": 3,
#         "overall_score": 3,
#         "label": "good",
#         "explanation": {
#             "accuracy": "While the core meaning is preserved, the omission of the specific detail about the wave's supposed destination results in a less accurate translation.",
#             "fluency": "While the translation avoids major grammatical errors, it contains a less natural phrasing that could benefit from refinement for fluency.",
#             "coherence": "Although there is a minor grammatical correction needed, the translation effectively preserves the logical flow and structure of the original sentence.",
#             "cultural_appropriateness": "While there is a slight deviation from the most common Filipino terms, the translation is still culturally appropriate and respectful.",
#             "guideline_adherence": "The translation uses correct domain-specific terms and adheres to the style rules for the chosen domain, even though there is a slight difference in sentence structure.",
#             "completeness": "The translation is mostly complete but lacks the specific phrase 'where it's supposed to be', which could alter the implied meaning of the source text."
#         }
#     }
# }
# --------------------
# {
#     "index": 61,
#     "source": "Sick of tea?! That's like being sick of breathing!",
#     "translation": "Ayaw mo na ng tsaa?! Parang sinabi mo na ring sawa ka nang huminga!",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 0,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 0,
#         "overall_score": 0,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation is inaccurate as it misinterprets the rhetorical nature and exaggeration of the source text, leading to a significant alteration of its meaning.",
#             "fluency": "The translation has noticeable grammatical errors and unnatural phrasing, failing to meet the criteria for fluency.",
#             "coherence": "The translation fails to preserve the logical structure and coherence of the original sentence.",
#             "cultural_appropriateness": "The translation lacks appropriate formality and uses an idiom that may not be understood or appreciated by all Filipinos, failing to respect cultural appropriateness.",
#             "guideline_adherence": "The translation uses the correct term for tea but incorrectly translates the concept of being tired/exhausted, failing to adhere to domain-specific style guidelines.",
#             "completeness": "The translation lacks crucial elements and fails to capture the full meaning and tone of the original sentence, indicating incompleteness."
#         }
#     }
# }
# --------------------
# {
#     "index": 62,
#     "source": "I wanted to invite my youngest to go get some ice cream, if he’ll let me.",
#     "translation": "Gusto ko imbitahin yung pinakabata kong anak para kumuha ng ice cream, kung papayagan niya ako.",
#     "reference": null,
#     "human_score": 3.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 1,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 2,
#         "overall_score": 2,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "The translation lacks accuracy in conveying the specific details and nuances of the source text, particularly in terms of the relationship between the speaker and the child, and the conditional aspect of the invitation.",
#             "fluency": "While the translation is mostly fluent and natural, it contains a few minor grammatical adjustments needed for better fluency.",
#             "coherence": "While the translation is coherent and maintains the logical flow, it could be slightly improved by adjusting the word order for better fluency.",
#             "cultural_appropriateness": "While the translation is mostly appropriate, it lacks the most precise term for 'youngest' and could benefit from a slight adjustment in phrasing for naturalness.",
#             "guideline_adherence": "While the translation conveys the general meaning, it contains inaccuracies and lacks clarity in certain phrases, which do not meet the guideline_adherence criterion.",
#             "completeness": "The translation lacks the conditional clause 'if he'll let me', which is crucial for conveying the full intention of the speaker. This omission indicates that the translation is not complete."
#         }
#     }
# }
# --------------------
# {
#     "index": 63,
#     "source": "That person has no more respect or love for you, leave them.",
#     "translation": "Wala nang respeto at pagmamahal yung tao para sa'yo, iwan mo na.",
#     "reference": null,
#     "human_score": 5.0,
#     "result": {
#         "criteria_scores": {
#             "accuracy": 0,
#             "fluency": 1,
#             "coherence": 0,
#             "cultural_appropriateness": 0,
#             "guideline_adherence": 0,
#             "completeness": 0
#         },
#         "raw_sum": 1,
#         "overall_score": 1,
#         "label": "poor",
#         "explanation": {
#             "accuracy": "While the translation captures the main idea of someone having no respect or love for the speaker and the need to distance oneself, it misses the emotional intensity implied by 'leave them.' This results in a score of 0 for accuracy.",
#             "fluency": "While the translation is mostly fluent, it could benefit from a more natural expression of leaving someone.",
#             "coherence": "Although the translation captures the essence of the source text, the omission of the final directive ('leave them') disrupts the coherent flow and structure of the sentence.",
#             "cultural_appropriateness": "The translation fails to meet the criterion of cultural appropriateness due to its lack of formalities and the absence of appropriate Filipino idioms and honorifics.",
#             "guideline_adherence": "While the translation follows basic Filipino grammar and structure, it fails to accurately convey the emotional context of the source text due to the incorrect use of terms.",
#             "completeness": "The translation is incomplete as it does not include the key directive to 'leave them,' which alters the overall message of the original sentence."
#         }
#     }
# }
# --------------------

# %%
# Check Consistency
import random
import statistics
from tqdm import tqdm

def is_valid_text(text):
    if text is None:
        return False
    if isinstance(text, float) and math.isnan(text):
        return False
    if isinstance(text, str) and text.strip().lower() == "nan":
        return False
    return True

filtered_dataset = [
    sample for sample in dataset
    if is_valid_text(sample.get("source")) and is_valid_text(sample.get("translation"))
]

K = min(5, len(filtered_dataset))
N = 5  # number of repeats
indices = random.sample(range(len(filtered_dataset)), K)
consistency_report = []

for idx in indices:
    sample = filtered_dataset[idx]
    scores = []
    # Wrap inner loop with tqdm for progress bar on repeats
    for _ in tqdm(range(N), desc=f"Evaluating sample {idx}", leave=False):
        out = planner.evaluate(sample)
        scores.append(out.get("overall_score"))
    mean = statistics.mean(scores)
    stdev = statistics.pstdev(scores) if mean != 0 else 0.0
    pct_var = (stdev / mean) * 100 if mean != 0 else 0.0
    consistency_report.append({
        "index": idx,
        "scores": scores,
        "mean": mean,
        "stdev": stdev,
        "pct_var": pct_var
    })

consistency_report
# Out:
# Evaluating sample 29:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 29:  20%|██        | 1/5 [02:07<08:28, 127.24s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 29:  40%|████      | 2/5 [04:05<06:06, 122.23s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 29:  60%|██████    | 3/5 [06:02<03:59, 119.77s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 29:  80%|████████  | 4/5 [07:59<01:58, 118.74s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 42:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 42:  20%|██        | 1/5 [01:59<07:58, 119.62s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 42:  40%|████      | 2/5 [03:54<05:50, 116.73s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 42:  60%|██████    | 3/5 [05:49<03:52, 116.15s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 42:  80%|████████  | 4/5 [07:48<01:57, 117.10s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 5:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 5:  20%|██        | 1/5 [01:55<07:43, 115.92s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 5:  40%|████      | 2/5 [04:03<06:08, 122.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 5:  60%|██████    | 3/5 [06:10<04:09, 124.91s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 5:  80%|████████  | 4/5 [08:20<02:06, 126.75s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 2:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 2:  20%|██        | 1/5 [01:31<06:05, 91.33s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 2:  40%|████      | 2/5 [03:19<05:03, 101.18s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 2:  60%|██████    | 3/5 [05:05<03:27, 103.58s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 2:  80%|████████  | 4/5 [06:32<01:36, 96.93s/it] The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 22:   0%|          | 0/5 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 22:  20%|██        | 1/5 [01:50<07:22, 110.52s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 22:  40%|████      | 2/5 [03:23<05:00, 100.20s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 22:  60%|██████    | 3/5 [05:12<03:28, 104.09s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating sample 22:  80%|████████  | 4/5 [07:04<01:47, 107.50s/it]The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [{'index': 29,
#   'scores': [2, 2, 2, 2, 2],
#   'mean': 2,
#   'stdev': 0.0,
#   'pct_var': 0.0},
#  {'index': 42,
#   'scores': [2, 2, 2, 2, 2],
#   'mean': 2,
#   'stdev': 0.0,
#   'pct_var': 0.0},
#  {'index': 5,
#   'scores': [0, 0, 0, 0, 0],
#   'mean': 0,
#   'stdev': 0.0,
#   'pct_var': 0.0},
#  {'index': 2,
#   'scores': [2, 2, 2, 2, 2],
#   'mean': 2,
#   'stdev': 0.0,
#   'pct_var': 0.0},
#  {'index': 22,
#   'scores': [4, 4, 4, 4, 4],
#   'mean': 4,
#   'stdev': 0.0,
#   'pct_var': 0.0}]

# %% [markdown]
# ## Evaluate Single Entry

# %%
import json
# Helper Function to evaluate single pairr
def evaluate_single_pair(source_text, translation_text, planner):
    sample = {
        "source": source_text,
        "translation": translation_text
    }
    try:
        result = planner.evaluate(sample)
    except Exception as e:
        result = {
            "error": str(e),
            "criteria_scores": {},
            "raw_sum": 0,
            "overall_score": 1,
            "label": "error",
            "explanation": {}
        }
    result_meta = {
        "source": sample["source"],
        "translation": sample["translation"],
        "result": result
    }
    return result_meta

# %%
# ENGLISH SOURCE TEXT
source_text = "It's raining cats and dogs."

# TAGALOG TRANSLATION
translation_text = "Umuulan ng pusa at aso."

evaluate_single_pair(source_text, translation_text, planner)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# {'source': "It's raining cats and dogs.",
#  'translation': 'Umuulan ng pusa at aso.',
#  'result': {'criteria_scores': {'accuracy': 0,
#    'fluency': 0,
#    'coherence': 0,
#    'cultural_appropriateness': 0,
#    'guideline_adherence': 0,
#    'completeness': 0},
#   'raw_sum': 0,
#   'overall_score': 0,
#   'label': 'poor',
#   'explanation': {'accuracy': 'The translation is inaccurate as it does not correctly represent the idiomatic expression of heavy rain in English.',
#    'fluency': 'Although the translation is grammatically correct, it fails to accurately convey the idiomatic meaning of the source text, making it unnatural for a native speaker.',
#    'coherence': 'The translation fails to preserve the metaphorical meaning and the logical structure of the source text.',
#    'cultural_appropriateness': "The translation does not accurately represent the cultural idiom of 'it's raining cats and dogs' in Filipino, failing to capture the intended meaning and cultural nuances.",
#    'guideline_adherence': "The translation uses a term ('pusa') that is not commonly used in Filipino for animals, and there is no specific domain guide for idiomatic expressions that would require adherence to a particular term.",
#    'completeness': "The translation fails to convey the idiomatic meaning of 'raining cats and dogs,' which is crucial to the original expression. Therefore, it scores 0 for not meeting the completeness criterion."}}}

# %%
# ENGLISH SOURCE TEXT
source_text = "INSERT"

# TAGALOG TRANSLATION
translation_text = "INSERT"

evaluate_single_pair(source_text, translation_text, planner)
